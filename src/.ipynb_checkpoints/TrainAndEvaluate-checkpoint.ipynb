# %%
# imports
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings('ignore')
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torch, os, torchvision
from torchvision import datasets, models, transforms
from pathlib import Path



from utils import display_images, imshow, train_model, plot_cf
ProjectRoot = Path().cwd().parent
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Food Recognition

# %% [markdown]
# # Data
#
# - Images of white rice and non white rice items has been download from Google Images using [Download All Images](https://add0n.com/save-images.html) chrome extension
# - For non white rice images following dishes has been used
#     - Dosa
#     - Idli
#     - Chapati
#
# - Reason behind choosing Dosa and Idli in the negative class category is that they share common color aspects with white rice, thus it easily helps to evaluate the models understanding of white rice.
#
# - 70% of white rice images has been used in training and 30% for testing
# - 70% of samples from Dosa, Idli and Chapati has been used in training and 30% fo testing

# %% [markdown]
# ## Data distribution

# %%
# sample view of images
display_images()
# Out:
# Class samples distribution in train:{'not_white_rice': 121, 'white_rice': 130}
# Class samples distribution in test:{'not_white_rice': 107, 'white_rice': 116}
#     <style>
#         #ipyplot-html-viewer-toggle-c2zKM534CWSQ67uouAh9ZA {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-c2zKM534CWSQ67uouAh9ZA {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-c2zKM534CWSQ67uouAh9ZA {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-c2zKM534CWSQ67uouAh9ZA:checked ~ #ipyplot-html-viewer-textarea-c2zKM534CWSQ67uouAh9ZA {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-c2zKM534CWSQ67uouAh9ZA:checked + #ipyplot-html-viewer-label-c2zKM534CWSQ67uouAh9ZA:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-c2zKM534CWSQ67uouAh9ZA">
#         <label id="ipyplot-html-viewer-label-c2zKM534CWSQ67uouAh9ZA" for="ipyplot-html-viewer-toggle-c2zKM534CWSQ67uouAh9ZA">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-c2zKM534CWSQ67uouAh9ZA" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-KYhCYPxBjTbsWLCRdSWt3K {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-KYhCYPxBjTbsWLCRdSWt3K">
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-Bh2UcB2BgTA84AnevXqxTG" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">not_white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-Bh2UcB2BgTA84AnevXqxTG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-2oGCjNh9WC4fqCxbDbNsW3" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-2oGCjNh9WC4fqCxbDbNsW3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-USSsTKQsjquZKnQ88UBtMS" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">not_white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-USSsTKQsjquZKnQ88UBtMS">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-Kh5rjfVut3FtA3Vmkw4AXa" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-Kh5rjfVut3FtA3Vmkw4AXa">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-iLFb4tCMDzMnSmosNFxPUm" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-iLFb4tCMDzMnSmosNFxPUm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-KjKX96mykqNH7ZWPYrdwSu" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">not_white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-KjKX96mykqNH7ZWPYrdwSu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-GFG8MNVTD67mb9jhDVvEwe" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">not_white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-GFG8MNVTD67mb9jhDVvEwe">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <style>
#         #ipyplot-imgs-container-div-KYhCYPxBjTbsWLCRdSWt3K {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-KYhCYPxBjTbsWLCRdSWt3K">
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-Bh2UcB2BgTA84AnevXqxTG" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">not_white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-Bh2UcB2BgTA84AnevXqxTG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-2oGCjNh9WC4fqCxbDbNsW3" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-2oGCjNh9WC4fqCxbDbNsW3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-USSsTKQsjquZKnQ88UBtMS" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">not_white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-USSsTKQsjquZKnQ88UBtMS">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-Kh5rjfVut3FtA3Vmkw4AXa" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-Kh5rjfVut3FtA3Vmkw4AXa">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-iLFb4tCMDzMnSmosNFxPUm" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-iLFb4tCMDzMnSmosNFxPUm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-KjKX96mykqNH7ZWPYrdwSu" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">not_white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-KjKX96mykqNH7ZWPYrdwSu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-GFG8MNVTD67mb9jhDVvEwe" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">not_white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-GFG8MNVTD67mb9jhDVvEwe">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-2uktmwcCe2howooKwKmG3b" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-2uktmwcCe2howooKwKmG3b">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-YjCjhDx9Jxikg8Q7PR663S" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">not_white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-YjCjhDx9Jxikg8Q7PR663S">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KYhCYPxBjTbsWLCRdSWt3K">
#         <div id="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K-9G48du7fc7BnXjW5aSJD9o" class="ipyplot-content-div-KYhCYPxBjTbsWLCRdSWt3K">
#             <h4 style="font-size: 12px; word-wrap: break-word;">white_rice</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>

# %% [markdown]
# # Model
#
# - Identifying whether white rice is in a image or not is a classical Image classification problem
# - Pre-trained ResNet18 on ImageNet has been fine tuned using transfer learning to perform this classification task

# %%
# defin pretrained resnet18 model
model = models.resnet18(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)
# push model to GPU
model = model.to(device)
# define loss function
criterion = nn.CrossEntropyLoss()
# define optimiser
optimizer_ft = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %% [markdown]
# # Train

# %% [markdown]
# ## Data Augmentations

# %%
# train and test augmentations
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((256,256)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# create pytorch datasets
data_dir = str(ProjectRoot/'data')
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'test']}

# create pytorch dataloaders
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=16,
                                             shuffle=True, num_workers=8)
              for x in ['train', 'test']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Train

# %%
trained_model = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, dataloaders, dataset_sizes, device, num_epochs=25, save_dir=ProjectRoot/'models')
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.4858 Acc: 0.8167
# test Loss: 0.2086 Acc: 0.9686
#
# Epoch 1/24
# ----------
# train Loss: 0.2091 Acc: 0.9363
# test Loss: 0.0806 Acc: 0.9865
#
# Epoch 2/24
# ----------
# train Loss: 0.0838 Acc: 0.9841
# test Loss: 0.0324 Acc: 1.0000
#
# Epoch 3/24
# ----------
# train Loss: 0.0660 Acc: 0.9880
# test Loss: 0.0173 Acc: 1.0000
#
# Epoch 4/24
# ----------
# train Loss: 0.0444 Acc: 0.9920
# test Loss: 0.0102 Acc: 1.0000
#
# Epoch 5/24
# ----------
# train Loss: 0.0893 Acc: 0.9562
# test Loss: 0.0074 Acc: 1.0000
#
# Epoch 6/24
# ----------
# train Loss: 0.0551 Acc: 0.9721
# test Loss: 0.0045 Acc: 1.0000
#
# Epoch 7/24
# ----------
# train Loss: 0.0151 Acc: 1.0000
# test Loss: 0.0049 Acc: 1.0000
#
# Epoch 8/24
# ----------
# train Loss: 0.0268 Acc: 0.9920
# test Loss: 0.0052 Acc: 1.0000
#
# Epoch 9/24
# ----------
# train Loss: 0.0174 Acc: 1.0000
# test Loss: 0.0046 Acc: 1.0000
#
# Epoch 10/24
# ----------
# train Loss: 0.0144 Acc: 1.0000
# test Loss: 0.0045 Acc: 1.0000
#
# Epoch 11/24
# ----------
# train Loss: 0.0148 Acc: 1.0000
# test Loss: 0.0044 Acc: 1.0000
#
# Epoch 12/24
# ----------
# train Loss: 0.0126 Acc: 1.0000
# test Loss: 0.0042 Acc: 1.0000
#
# Epoch 13/24
# ----------
# train Loss: 0.0211 Acc: 1.0000
# test Loss: 0.0042 Acc: 1.0000
#
# Epoch 14/24
# ----------
# train Loss: 0.0125 Acc: 1.0000
# test Loss: 0.0041 Acc: 1.0000
#
# Epoch 15/24
# ----------
# train Loss: 0.0100 Acc: 1.0000
# test Loss: 0.0042 Acc: 1.0000
#
# Epoch 16/24
# ----------
# train Loss: 0.0140 Acc: 1.0000
# test Loss: 0.0042 Acc: 1.0000
#
# Epoch 17/24
# ----------
# train Loss: 0.0183 Acc: 1.0000
# test Loss: 0.0041 Acc: 1.0000
#
# Epoch 18/24
# ----------
# train Loss: 0.0167 Acc: 1.0000
# test Loss: 0.0041 Acc: 1.0000
#
# Epoch 19/24
# ----------
# train Loss: 0.0133 Acc: 1.0000
# test Loss: 0.0041 Acc: 1.0000
#
# Epoch 20/24
# ----------
# train Loss: 0.0143 Acc: 1.0000
# test Loss: 0.0040 Acc: 1.0000
#
# Epoch 21/24
# ----------
# train Loss: 0.0138 Acc: 1.0000
# test Loss: 0.0042 Acc: 1.0000
#
# Epoch 22/24
# ----------
# train Loss: 0.0126 Acc: 1.0000
# test Loss: 0.0040 Acc: 1.0000
#
# Epoch 23/24
# ----------
# train Loss: 0.0197 Acc: 1.0000
# test Loss: 0.0043 Acc: 1.0000
#
# Epoch 24/24
# ----------
# train Loss: 0.0172 Acc: 1.0000
# test Loss: 0.0042 Acc: 1.0000
#
# Training complete in 1m 30s
# Best test Acc: 1.000000

# %% [markdown]
# # Evaluate

# %%
from IPython.display import Image as IImage
from IPython.display import display
from PIL import Image
from pprint import pprint
from sklearn.metrics import classification_report, plot_confusion_matrix, plot_precision_recall_curve, plot_roc_curve

# set model to eval model
model.eval()
classes = ['not_white_rice', 'white_rice']
y_true, y_pred = [], []
for img_pth in Path('/home/satish27may/Foodie/data/test').glob('*/*'):
    image = Image.open(img_pth)
    test_transforms = transforms.Compose([
        transforms.Resize((256,256)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    image_tensor = test_transforms(image)
    image_tensor = image_tensor.unsqueeze(0)

    
    output = model(image_tensor.cuda())
    pred_cls = classes[output.data.cpu().numpy().argmax()]
    y_pred.append(pred_cls)
    y_true.append(img_pth.parent.name)
    if img_pth.parent.name!=pred_cls:
        display(IImage(filename=str(img_pth)))
        print(pred_cls, np.max(torch.softmax(output,dim=1).data.cpu().numpy()), img_pth.parent.name)

# %%
# classification report
print(classification_report(y_true, y_pred, labels=classes))
# Out:
#                 precision    recall  f1-score   support
#
# not_white_rice       1.00      1.00      1.00       107
#     white_rice       1.00      1.00      1.00       116
#
#       accuracy                           1.00       223
#      macro avg       1.00      1.00      1.00       223
#   weighted avg       1.00      1.00      1.00       223

# %%
# confusion matrix
plot_cf(y_true, y_pred, class_names)
# Out:
# [[1. 0.]
#  [0. 1.]]
